# %%
print(1)
# Out:
# 1

# %%
class MyWorld:
    def __init__(self, a1, a2):
        self.a1 = a1
        self.a2 = a2
    def display(self):
        print(self.a1, self.a2)
    def __str__(self):
        return f"{self.a1}" 


world1 = MyWorld("an", "ki")

# %%
from abc import ABC, abstractmethod


class Vehicle(ABC):

    @abstractmethod
    def start(self):
        pass


class Car:

    pass

class Bike(Vehicle):

    def start(self):
        print("Bike starts using a button")


car = Car()
car

# %%
world1.a3 = 5

# %%
world1.a3
# Out:
# 5
